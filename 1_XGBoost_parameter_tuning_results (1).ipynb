# %%
import pandas as pd
import ast
from pprint import pformat

csv_path = "/Users/mazin/Desktop/hyperopt_live_log.csv"

def parse_params(s):
    if isinstance(s, str) and s.strip().startswith("{"):
        try:
            return ast.literal_eval(s)
        except Exception:
            return s
    return s

def round_floats(obj, ndigits=6):
    if isinstance(obj, float):
        return round(obj, ndigits)
    if isinstance(obj, dict):
        return {k: round_floats(v, ndigits) for k, v in obj.items()}
    if isinstance(obj, (list, tuple)):
        return type(obj)(round_floats(v, ndigits) for v in obj)
    return obj

def print_row(row, title):
    print(f"\n===== {title} =====")
    print(f"Iteration   : {int(row['iteration']) if pd.notna(row['iteration']) else row['iteration']}")
    if 'timestamp_dt' in row and pd.notna(row['timestamp_dt']):
        print(f"Timestamp   : {row['timestamp_dt']}")
    elif 'timestamp' in row and pd.notna(row['timestamp']):
        print(f"Timestamp   : {pd.to_datetime(row['timestamp'], unit='s', errors='coerce')}")
    print(f"train_mse   : {row['train_mse']:.6f}")
    print(f"test_mse    : {row['test_mse']:.6f}")
    print(f"train_r2    : {row['train_r2']:.6f}")
    print(f"test_r2     : {row['test_r2']:.6f}")
    params = row.get('params', None)
    if params is not None:
        params = round_floats(params, 6)
        print("params      :")
        print(pformat(params, width=100, sort_dicts=True))

# --- load & clean ---
df = pd.read_csv(csv_path, converters={"params": parse_params})
for c in ["train_mse", "train_r2", "test_mse", "test_r2"]:
    df[c] = pd.to_numeric(df[c], errors="coerce")
if "timestamp" in df.columns:
    df["timestamp_dt"] = pd.to_datetime(df["timestamp"], unit="s", errors="coerce")

# --- locate winners ---
print_row(df.loc[df["train_mse"].idxmin()], "Lowest train_mse")
print_row(df.loc[df["test_mse"].idxmin()],  "Lowest test_mse")
print_row(df.loc[df["train_r2"].idxmax()],  "Highest train_r2")
print_row(df.loc[df["test_r2"].idxmax()],   "Highest test_r2")
# Out:
# ===== Lowest train_mse =====
# Iteration   : 249
# Timestamp   : 2025-08-08 17:45:44.365824
# train_mse   : 0.005010
# test_mse    : 0.018217
# train_r2    : 0.833303
# test_r2     : -0.376188
# params      :
# {'colsample_bytree': 0.360569,
#  'device': 'cuda',
#  'gamma': 0.003303,
#  'learning_rate': 0.184417,
#  'max_depth': 9,
#  'min_child_weight': 8,
#  'n_estimators': 3250,
#  'n_jobs': -1,
#  'objective': 'reg:squarederror',
#  'random_state': 42,
#  'reg_alpha': 24.718484,
#  'reg_lambda': 4214.830235,
#  'subsample': 0.547832}
#
# ===== Lowest test_mse =====
# Iteration   : 741
# Timestamp   : 2025-08-08 18:07:16.230345472
# train_mse   : 0.028682
# test_mse    : 0.013105
# train_r2    : 0.045608
# test_r2     : 0.009950
# params      :
# {'colsample_bytree': 0.500413,
#  'device': 'cuda',
#  'gamma': 1.077876,
#  'learning_rate': 0.208581,
#  'max_depth': 14,
#  'min_child_weight': 8,
#  'n_estimators': 2150,
#  'n_jobs': -1,
#  'objective': 'reg:squarederror',
#  'random_state': 42,
#  'reg_alpha': 220.784026,
#  'reg_lambda': 3650.307704,
#  'subsample': 0.876951}
#
# ===== Highest train_r2 =====
# Iteration   : 249
# Timestamp   : 2025-08-08 17:45:44.365824
# train_mse   : 0.005010
# test_mse    : 0.018217
# train_r2    : 0.833303
# test_r2     : -0.376188
# params      :
# {'colsample_bytree': 0.360569,
#  'device': 'cuda',
#  'gamma': 0.003303,
#  'learning_rate': 0.184417,
#  'max_depth': 9,
#  'min_child_weight': 8,
#  'n_estimators': 3250,
#  'n_jobs': -1,
#  'objective': 'reg:squarederror',
#  'random_state': 42,
#  'reg_alpha': 24.718484,
#  'reg_lambda': 4214.830235,
#  'subsample': 0.547832}
#
# ===== Highest test_r2 =====
# Iteration   : 741
# Timestamp   : 2025-08-08 18:07:16.230345472
# train_mse   : 0.028682
# test_mse    : 0.013105
# train_r2    : 0.045608
# test_r2     : 0.009950
# params      :
# {'colsample_bytree': 0.500413,
#  'device': 'cuda',
#  'gamma': 1.077876,
#  'learning_rate': 0.208581,
#  'max_depth': 14,
#  'min_child_weight': 8,
#  'n_estimators': 2150,
#  'n_jobs': -1,
#  'objective': 'reg:squarederror',
#  'random_state': 42,
#  'reg_alpha': 220.784026,
#  'reg_lambda': 3650.307704,
#  'subsample': 0.876951}

# %%
import pandas as pd
import ast
from math import isnan

# --- path ---
csv_path = "/Users/mazin/Desktop/hyperopt_live_log.csv"

# ---------- helpers ----------
def parse_params(s):
    if isinstance(s, str) and s.strip().startswith("{"):
        try:
            return ast.literal_eval(s)
        except Exception:
            return s
    return s

def fmt(x, nd=6):
    if isinstance(x, float):
        try:
            if isnan(x): return "NaN"
        except Exception:
            pass
        return f"{x:.{nd}f}"
    return str(x)

def pretty_params(p, nd=6, indent="  "):
    if not isinstance(p, dict):
        return indent + str(p)
    # sort keys for stability, round floats
    lines = []
    for k in sorted(p.keys()):
        v = p[k]
        if isinstance(v, float):
            v = float(f"{v:.{nd}g}")
        lines.append(f"{indent}{k}: {v}")
    return "\n".join(lines)

def human_time(raw):
    try:
        return pd.to_datetime(raw, unit="s", errors="coerce")
    except Exception:
        return pd.NaT

def print_full_row(row, key_metric, rank):
    # header line with the key value
    it = int(row["iteration"]) if pd.notna(row.get("iteration")) else "NA"
    ts_raw = row.get("timestamp", None)
    ts_human = row.get("timestamp_dt", None)
    if ts_human is pd.NaT or ts_human is None:
        ts_human = human_time(ts_raw)
    ts_human_str = "" if pd.isna(ts_human) else str(ts_human)

    key_val = row[key_metric]
    print(f"#{rank:02d} — {key_metric}: {fmt(key_val)}  (iteration {it}, time {ts_human_str})")

    # full row (all columns) for reference, formatted line-by-line
    print("  ── Full row:")
    for col in row.index:
        if col == "params":
            print(f"    {col}:")
            print(pretty_params(row[col], indent="      "))
        elif col == "timestamp_dt":
            # show the human time only once; still include the field name
            print(f"    {col}: {ts_human_str}")
        elif col in ("train_mse", "test_mse", "train_r2", "test_r2"):
            print(f"    {col}: {fmt(row[col])}")
        else:
            print(f"    {col}: {row[col]}")
    print("")  # blank line after each block

def print_section(df, sort_by, ascending, title, topn=20):
    print("=" * 100)
    print(title)
    print("=" * 100)

    # rank & iterate
    subset = (
        df.sort_values(sort_by, ascending=ascending, na_position="last")
          .head(min(topn, len(df)))
    )
    for r, (_, row) in enumerate(subset.iterrows(), start=1):
        print_full_row(row, key_metric=sort_by, rank=r)

# ---------- load & clean ----------
df = pd.read_csv(csv_path, converters={"params": parse_params})

# ensure numeric
for c in ["train_mse", "train_r2", "test_mse", "test_r2"]:
    df[c] = pd.to_numeric(df[c], errors="coerce")

# human timestamp column
if "timestamp" in df.columns:
    df["timestamp_dt"] = pd.to_datetime(df["timestamp"], unit="s", errors="coerce")

# ---------- print the four ranked lists ----------
print_section(df, "train_mse", True,  "Top 20 LOWEST train_mse")
print_section(df, "test_mse",  True,  "Top 20 LOWEST test_mse")
print_section(df, "train_r2",  False, "Top 20 HIGHEST train_r2")
print_section(df, "test_r2",   False, "Top 20 HIGHEST test_r2")
# Out:
# ====================================================================================================
# Top 20 LOWEST train_mse
# ====================================================================================================
# #01 — train_mse: 0.005010  (iteration 249, time 2025-08-08 17:45:44.365824)
#   ── Full row:
#     iteration: 249
#     train_mse: 0.005010
#     train_r2: 0.833303
#     test_mse: 0.018217
#     test_r2: -0.376188
#     params:
#       colsample_bytree: 0.360569
#       device: cuda
#       gamma: 0.00330282
#       learning_rate: 0.184417
#       max_depth: 9
#       min_child_weight: 8
#       n_estimators: 3250
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 24.7185
#       reg_lambda: 4214.83
#       subsample: 0.547832
#     timestamp: 1754675144.365824
#     timestamp_dt: 2025-08-08 17:45:44.365824
#
# #02 — train_mse: 0.008481  (iteration 681, time 2025-08-08 18:04:30.457833984)
#   ── Full row:
#     iteration: 681
#     train_mse: 0.008481
#     train_r2: 0.717809
#     test_mse: 0.016640
#     test_r2: -0.257106
#     params:
#       colsample_bytree: 0.449734
#       device: cuda
#       gamma: 0.0327927
#       learning_rate: 0.129122
#       max_depth: 6
#       min_child_weight: 10
#       n_estimators: 1850
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 14.5341
#       reg_lambda: 1177.81
#       subsample: 0.911686
#     timestamp: 1754676270.457834
#     timestamp_dt: 2025-08-08 18:04:30.457833984
#
# #03 — train_mse: 0.009588  (iteration 382, time 2025-08-08 17:52:20.129754368)
#   ── Full row:
#     iteration: 382
#     train_mse: 0.009588
#     train_r2: 0.680952
#     test_mse: 0.015351
#     test_r2: -0.159725
#     params:
#       colsample_bytree: 0.390525
#       device: cuda
#       gamma: 0.122221
#       learning_rate: 0.179353
#       max_depth: 11
#       min_child_weight: 9
#       n_estimators: 3550
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 0.884505
#       reg_lambda: 3955.08
#       subsample: 0.985095
#     timestamp: 1754675540.1297543
#     timestamp_dt: 2025-08-08 17:52:20.129754368
#
# #04 — train_mse: 0.009808  (iteration 956, time 2025-08-08 18:18:04.205077504)
#   ── Full row:
#     iteration: 956
#     train_mse: 0.009808
#     train_r2: 0.673643
#     test_mse: 0.014630
#     test_r2: -0.105202
#     params:
#       colsample_bytree: 0.48405
#       device: cuda
#       gamma: 0.216204
#       learning_rate: 0.134295
#       max_depth: 14
#       min_child_weight: 8
#       n_estimators: 1600
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 0.0571033
#       reg_lambda: 2632.02
#       subsample: 0.953736
#     timestamp: 1754677084.2050774
#     timestamp_dt: 2025-08-08 18:18:04.205077504
#
# #05 — train_mse: 0.010122  (iteration 689, time 2025-08-08 18:04:52.510065408)
#   ── Full row:
#     iteration: 689
#     train_mse: 0.010122
#     train_r2: 0.663190
#     test_mse: 0.015194
#     test_r2: -0.147827
#     params:
#       colsample_bytree: 0.282048
#       device: cuda
#       gamma: 0.165751
#       learning_rate: 0.1386
#       max_depth: 9
#       min_child_weight: 12
#       n_estimators: 3150
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 0.0638032
#       reg_lambda: 1405.61
#       subsample: 0.863396
#     timestamp: 1754676292.5100653
#     timestamp_dt: 2025-08-08 18:04:52.510065408
#
# #06 — train_mse: 0.010529  (iteration 748, time 2025-08-08 18:07:33.701985792)
#   ── Full row:
#     iteration: 748
#     train_mse: 0.010529
#     train_r2: 0.649633
#     test_mse: 0.015028
#     test_r2: -0.135311
#     params:
#       colsample_bytree: 0.56739
#       device: cuda
#       gamma: 0.21292
#       learning_rate: 0.215117
#       max_depth: 14
#       min_child_weight: 9
#       n_estimators: 1500
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 5.24811
#       reg_lambda: 2702.64
#       subsample: 0.883699
#     timestamp: 1754676453.7019858
#     timestamp_dt: 2025-08-08 18:07:33.701985792
#
# #07 — train_mse: 0.011080  (iteration 569, time 2025-08-08 17:59:40.086947072)
#   ── Full row:
#     iteration: 569
#     train_mse: 0.011080
#     train_r2: 0.631326
#     test_mse: 0.014878
#     test_r2: -0.123972
#     params:
#       colsample_bytree: 0.602452
#       device: cuda
#       gamma: 0.00575772
#       learning_rate: 0.150733
#       max_depth: 11
#       min_child_weight: 12
#       n_estimators: 150
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 6.9004
#       reg_lambda: 3665.91
#       subsample: 0.915792
#     timestamp: 1754675980.086947
#     timestamp_dt: 2025-08-08 17:59:40.086947072
#
# #08 — train_mse: 0.011772  (iteration 482, time 2025-08-08 17:55:06.548829696)
#   ── Full row:
#     iteration: 482
#     train_mse: 0.011772
#     train_r2: 0.608284
#     test_mse: 0.015226
#     test_r2: -0.150227
#     params:
#       colsample_bytree: 0.368509
#       device: cuda
#       gamma: 0.0826047
#       learning_rate: 0.111115
#       max_depth: 8
#       min_child_weight: 9
#       n_estimators: 500
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 12.8563
#       reg_lambda: 3347.82
#       subsample: 0.971042
#     timestamp: 1754675706.5488298
#     timestamp_dt: 2025-08-08 17:55:06.548829696
#
# #09 — train_mse: 0.012305  (iteration 477, time 2025-08-08 17:54:58.830246656)
#   ── Full row:
#     iteration: 477
#     train_mse: 0.012305
#     train_r2: 0.590538
#     test_mse: 0.014445
#     test_r2: -0.091283
#     params:
#       colsample_bytree: 0.431171
#       device: cuda
#       gamma: 0.251761
#       learning_rate: 0.0911019
#       max_depth: 13
#       min_child_weight: 10
#       n_estimators: 650
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 11.1112
#       reg_lambda: 2353.15
#       subsample: 0.983271
#     timestamp: 1754675698.8302467
#     timestamp_dt: 2025-08-08 17:54:58.830246656
#
# #10 — train_mse: 0.012578  (iteration 369, time 2025-08-08 17:51:42.106733056)
#   ── Full row:
#     iteration: 369
#     train_mse: 0.012578
#     train_r2: 0.581456
#     test_mse: 0.014670
#     test_r2: -0.108229
#     params:
#       colsample_bytree: 0.429607
#       device: cuda
#       gamma: 0.309094
#       learning_rate: 0.201217
#       max_depth: 24
#       min_child_weight: 12
#       n_estimators: 2350
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 1.53806
#       reg_lambda: 5160.84
#       subsample: 0.961549
#     timestamp: 1754675502.106733
#     timestamp_dt: 2025-08-08 17:51:42.106733056
#
# #11 — train_mse: 0.013490  (iteration 990, time 2025-08-08 18:19:45.643872512)
#   ── Full row:
#     iteration: 990
#     train_mse: 0.013490
#     train_r2: 0.551131
#     test_mse: 0.014055
#     test_r2: -0.061769
#     params:
#       colsample_bytree: 0.459051
#       device: cuda
#       gamma: 0.340061
#       learning_rate: 0.0931071
#       max_depth: 12
#       min_child_weight: 10
#       n_estimators: 1300
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 3.56998
#       reg_lambda: 1886.06
#       subsample: 0.923
#     timestamp: 1754677185.6438725
#     timestamp_dt: 2025-08-08 18:19:45.643872512
#
# #12 — train_mse: 0.013593  (iteration 838, time 2025-08-08 18:12:03.660814336)
#   ── Full row:
#     iteration: 838
#     train_mse: 0.013593
#     train_r2: 0.547702
#     test_mse: 0.014929
#     test_r2: -0.127810
#     params:
#       colsample_bytree: 0.536197
#       device: cuda
#       gamma: 0.18965
#       learning_rate: 0.159346
#       max_depth: 9
#       min_child_weight: 11
#       n_estimators: 1800
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 14.0238
#       reg_lambda: 3745.74
#       subsample: 0.983713
#     timestamp: 1754676723.6608143
#     timestamp_dt: 2025-08-08 18:12:03.660814336
#
# #13 — train_mse: 0.014209  (iteration 759, time 2025-08-08 18:08:04.423654144)
#   ── Full row:
#     iteration: 759
#     train_mse: 0.014209
#     train_r2: 0.527189
#     test_mse: 0.014144
#     test_r2: -0.068510
#     params:
#       colsample_bytree: 0.455343
#       device: cuda
#       gamma: 0.640364
#       learning_rate: 0.210019
#       max_depth: 15
#       min_child_weight: 11
#       n_estimators: 2050
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 0.948199
#       reg_lambda: 813.136
#       subsample: 0.880269
#     timestamp: 1754676484.423654
#     timestamp_dt: 2025-08-08 18:08:04.423654144
#
# #14 — train_mse: 0.014583  (iteration 335, time 2025-08-08 17:50:04.059897088)
#   ── Full row:
#     iteration: 335
#     train_mse: 0.014583
#     train_r2: 0.514747
#     test_mse: 0.014760
#     test_r2: -0.115070
#     params:
#       colsample_bytree: 0.507286
#       device: cuda
#       gamma: 0.316546
#       learning_rate: 0.279661
#       max_depth: 22
#       min_child_weight: 11
#       n_estimators: 1550
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 14.6176
#       reg_lambda: 3725.58
#       subsample: 0.80845
#     timestamp: 1754675404.0598972
#     timestamp_dt: 2025-08-08 17:50:04.059897088
#
# #15 — train_mse: 0.014796  (iteration 491, time 2025-08-08 17:55:28.081819904)
#   ── Full row:
#     iteration: 491
#     train_mse: 0.014796
#     train_r2: 0.507676
#     test_mse: 0.015017
#     test_r2: -0.134450
#     params:
#       colsample_bytree: 0.379059
#       device: cuda
#       gamma: 0.195717
#       learning_rate: 0.160482
#       max_depth: 7
#       min_child_weight: 13
#       n_estimators: 1400
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 12.7782
#       reg_lambda: 2912.1
#       subsample: 0.969727
#     timestamp: 1754675728.08182
#     timestamp_dt: 2025-08-08 17:55:28.081819904
#
# #16 — train_mse: 0.015301  (iteration 297, time 2025-08-08 17:48:00.627092992)
#   ── Full row:
#     iteration: 297
#     train_mse: 0.015301
#     train_r2: 0.490879
#     test_mse: 0.014347
#     test_r2: -0.083876
#     params:
#       colsample_bytree: 0.820275
#       device: cuda
#       gamma: 0.601108
#       learning_rate: 0.184466
#       max_depth: 14
#       min_child_weight: 8
#       n_estimators: 2200
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 2.18328
#       reg_lambda: 2444.49
#       subsample: 0.983654
#     timestamp: 1754675280.627093
#     timestamp_dt: 2025-08-08 17:48:00.627092992
#
# #17 — train_mse: 0.015399  (iteration 303, time 2025-08-08 17:48:20.640445184)
#   ── Full row:
#     iteration: 303
#     train_mse: 0.015399
#     train_r2: 0.487595
#     test_mse: 0.014220
#     test_r2: -0.074223
#     params:
#       colsample_bytree: 0.565748
#       device: cuda
#       gamma: 0.413392
#       learning_rate: 0.150066
#       max_depth: 21
#       min_child_weight: 11
#       n_estimators: 2500
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 17.4095
#       reg_lambda: 3560.58
#       subsample: 0.924913
#     timestamp: 1754675300.6404452
#     timestamp_dt: 2025-08-08 17:48:20.640445184
#
# #18 — train_mse: 0.015954  (iteration 620, time 2025-08-08 18:02:07.729071616)
#   ── Full row:
#     iteration: 620
#     train_mse: 0.015954
#     train_r2: 0.469134
#     test_mse: 0.014153
#     test_r2: -0.069179
#     params:
#       colsample_bytree: 0.413967
#       device: cuda
#       gamma: 0.342243
#       learning_rate: 0.192011
#       max_depth: 9
#       min_child_weight: 7
#       n_estimators: 2800
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 11.5402
#       reg_lambda: 3428.79
#       subsample: 0.982367
#     timestamp: 1754676127.7290716
#     timestamp_dt: 2025-08-08 18:02:07.729071616
#
# #19 — train_mse: 0.016272  (iteration 975, time 2025-08-08 18:19:01.182672384)
#   ── Full row:
#     iteration: 975
#     train_mse: 0.016272
#     train_r2: 0.458547
#     test_mse: 0.014507
#     test_r2: -0.095967
#     params:
#       colsample_bytree: 0.569755
#       device: cuda
#       gamma: 0.727008
#       learning_rate: 0.266131
#       max_depth: 14
#       min_child_weight: 9
#       n_estimators: 2400
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 4.9716
#       reg_lambda: 1497.04
#       subsample: 0.91505
#     timestamp: 1754677141.1826725
#     timestamp_dt: 2025-08-08 18:19:01.182672384
#
# #20 — train_mse: 0.016413  (iteration 188, time 2025-08-08 17:42:06.604801024)
#   ── Full row:
#     iteration: 188
#     train_mse: 0.016413
#     train_r2: 0.453853
#     test_mse: 0.013909
#     test_r2: -0.050730
#     params:
#       colsample_bytree: 0.392856
#       device: cuda
#       gamma: 0.461047
#       learning_rate: 0.117176
#       max_depth: 9
#       min_child_weight: 9
#       n_estimators: 3000
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 1.21086
#       reg_lambda: 2353.91
#       subsample: 0.977964
#     timestamp: 1754674926.604801
#     timestamp_dt: 2025-08-08 17:42:06.604801024
#
# ====================================================================================================
# Top 20 LOWEST test_mse
# ====================================================================================================
# #01 — test_mse: 0.013105  (iteration 741, time 2025-08-08 18:07:16.230345472)
#   ── Full row:
#     iteration: 741
#     train_mse: 0.028682
#     train_r2: 0.045608
#     test_mse: 0.013105
#     test_r2: 0.009950
#     params:
#       colsample_bytree: 0.500413
#       device: cuda
#       gamma: 1.07788
#       learning_rate: 0.208581
#       max_depth: 14
#       min_child_weight: 8
#       n_estimators: 2150
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 220.784
#       reg_lambda: 3650.31
#       subsample: 0.876951
#     timestamp: 1754676436.2303455
#     timestamp_dt: 2025-08-08 18:07:16.230345472
#
# #02 — test_mse: 0.013138  (iteration 808, time 2025-08-08 18:10:27.705774848)
#   ── Full row:
#     iteration: 808
#     train_mse: 0.028512
#     train_r2: 0.051271
#     test_mse: 0.013138
#     test_r2: 0.007447
#     params:
#       colsample_bytree: 0.492154
#       device: cuda
#       gamma: 1.28789
#       learning_rate: 0.147052
#       max_depth: 8
#       min_child_weight: 10
#       n_estimators: 2550
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 175.098
#       reg_lambda: 4315.91
#       subsample: 0.873144
#     timestamp: 1754676627.7057748
#     timestamp_dt: 2025-08-08 18:10:27.705774848
#
# #03 — test_mse: 0.013141  (iteration 194, time 2025-08-08 17:42:25.917345792)
#   ── Full row:
#     iteration: 194
#     train_mse: 0.029373
#     train_r2: 0.022615
#     test_mse: 0.013141
#     test_r2: 0.007232
#     params:
#       colsample_bytree: 0.379297
#       device: cuda
#       gamma: 0.120228
#       learning_rate: 0.160559
#       max_depth: 8
#       min_child_weight: 10
#       n_estimators: 3300
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 611.589
#       reg_lambda: 3707.07
#       subsample: 0.971439
#     timestamp: 1754674945.9173458
#     timestamp_dt: 2025-08-08 17:42:25.917345792
#
# #04 — test_mse: 0.013151  (iteration 505, time 2025-08-08 17:55:59.500998400)
#   ── Full row:
#     iteration: 505
#     train_mse: 0.028409
#     train_r2: 0.054695
#     test_mse: 0.013151
#     test_r2: 0.006460
#     params:
#       colsample_bytree: 0.409729
#       device: cuda
#       gamma: 0.723668
#       learning_rate: 0.148242
#       max_depth: 9
#       min_child_weight: 9
#       n_estimators: 3750
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 220.347
#       reg_lambda: 2276.78
#       subsample: 0.847024
#     timestamp: 1754675759.5009985
#     timestamp_dt: 2025-08-08 17:55:59.500998400
#
# #05 — test_mse: 0.013154  (iteration 631, time 2025-08-08 18:02:35.640585984)
#   ── Full row:
#     iteration: 631
#     train_mse: 0.027468
#     train_r2: 0.086019
#     test_mse: 0.013154
#     test_r2: 0.006300
#     params:
#       colsample_bytree: 0.541007
#       device: cuda
#       gamma: 0.791514
#       learning_rate: 0.149848
#       max_depth: 9
#       min_child_weight: 10
#       n_estimators: 1750
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 134.005
#       reg_lambda: 3529.96
#       subsample: 0.838053
#     timestamp: 1754676155.640586
#     timestamp_dt: 2025-08-08 18:02:35.640585984
#
# #06 — test_mse: 0.013157  (iteration 451, time 2025-08-08 17:54:18.900998144)
#   ── Full row:
#     iteration: 451
#     train_mse: 0.029255
#     train_r2: 0.026551
#     test_mse: 0.013157
#     test_r2: 0.006014
#     params:
#       colsample_bytree: 0.470671
#       device: cuda
#       gamma: 0.469475
#       learning_rate: 0.18007
#       max_depth: 7
#       min_child_weight: 8
#       n_estimators: 1450
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 409.476
#       reg_lambda: 2681.08
#       subsample: 0.848005
#     timestamp: 1754675658.900998
#     timestamp_dt: 2025-08-08 17:54:18.900998144
#
# #07 — test_mse: 0.013158  (iteration 186, time 2025-08-08 17:41:59.875205120)
#   ── Full row:
#     iteration: 186
#     train_mse: 0.027764
#     train_r2: 0.076165
#     test_mse: 0.013158
#     test_r2: 0.005956
#     params:
#       colsample_bytree: 0.659737
#       device: cuda
#       gamma: 0.473135
#       learning_rate: 0.209381
#       max_depth: 13
#       min_child_weight: 10
#       n_estimators: 2100
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 250.712
#       reg_lambda: 3676.15
#       subsample: 0.999136
#     timestamp: 1754674919.875205
#     timestamp_dt: 2025-08-08 17:41:59.875205120
#
# #08 — test_mse: 0.013163  (iteration 469, time 2025-08-08 17:54:47.793163008)
#   ── Full row:
#     iteration: 469
#     train_mse: 0.028490
#     train_r2: 0.052006
#     test_mse: 0.013163
#     test_r2: 0.005624
#     params:
#       colsample_bytree: 0.42213
#       device: cuda
#       gamma: 0.810567
#       learning_rate: 0.110057
#       max_depth: 10
#       min_child_weight: 10
#       n_estimators: 850
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 208.497
#       reg_lambda: 2277.4
#       subsample: 0.892466
#     timestamp: 1754675687.793163
#     timestamp_dt: 2025-08-08 17:54:47.793163008
#
# #09 — test_mse: 0.013163  (iteration 711, time 2025-08-08 18:05:45.434233600)
#   ── Full row:
#     iteration: 711
#     train_mse: 0.028115
#     train_r2: 0.064464
#     test_mse: 0.013163
#     test_r2: 0.005601
#     params:
#       colsample_bytree: 0.517818
#       device: cuda
#       gamma: 1.06602
#       learning_rate: 0.133584
#       max_depth: 6
#       min_child_weight: 7
#       n_estimators: 2450
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 152.123
#       reg_lambda: 3625.2
#       subsample: 0.9034
#     timestamp: 1754676345.4342337
#     timestamp_dt: 2025-08-08 18:05:45.434233600
#
# #10 — test_mse: 0.013164  (iteration 389, time 2025-08-08 17:52:39.363936)
#   ── Full row:
#     iteration: 389
#     train_mse: 0.028865
#     train_r2: 0.039515
#     test_mse: 0.013164
#     test_r2: 0.005528
#     params:
#       colsample_bytree: 0.344951
#       device: cuda
#       gamma: 0.854488
#       learning_rate: 0.122423
#       max_depth: 5
#       min_child_weight: 10
#       n_estimators: 450
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 207.242
#       reg_lambda: 6219.59
#       subsample: 0.828809
#     timestamp: 1754675559.363936
#     timestamp_dt: 2025-08-08 17:52:39.363936
#
# #11 — test_mse: 0.013170  (iteration 943, time 2025-08-08 18:17:28.532270848)
#   ── Full row:
#     iteration: 943
#     train_mse: 0.028401
#     train_r2: 0.054960
#     test_mse: 0.013170
#     test_r2: 0.005083
#     params:
#       colsample_bytree: 0.50607
#       device: cuda
#       gamma: 1.058
#       learning_rate: 0.0731066
#       max_depth: 10
#       min_child_weight: 13
#       n_estimators: 1950
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 171.891
#       reg_lambda: 3692.59
#       subsample: 0.841883
#     timestamp: 1754677048.532271
#     timestamp_dt: 2025-08-08 18:17:28.532270848
#
# #12 — test_mse: 0.013171  (iteration 921, time 2025-08-08 18:16:16.081352704)
#   ── Full row:
#     iteration: 921
#     train_mse: 0.029271
#     train_r2: 0.026014
#     test_mse: 0.013171
#     test_r2: 0.005018
#     params:
#       colsample_bytree: 0.624017
#       device: cuda
#       gamma: 0.264118
#       learning_rate: 0.198227
#       max_depth: 6
#       min_child_weight: 6
#       n_estimators: 950
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 459.194
#       reg_lambda: 2483.01
#       subsample: 0.877294
#     timestamp: 1754676976.0813527
#     timestamp_dt: 2025-08-08 18:16:16.081352704
#
# #13 — test_mse: 0.013171  (iteration 187, time 2025-08-08 17:42:02.580443136)
#   ── Full row:
#     iteration: 187
#     train_mse: 0.028129
#     train_r2: 0.064001
#     test_mse: 0.013171
#     test_r2: 0.004998
#     params:
#       colsample_bytree: 0.392667
#       device: cuda
#       gamma: 0.480634
#       learning_rate: 0.159308
#       max_depth: 13
#       min_child_weight: 10
#       n_estimators: 2100
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 250.986
#       reg_lambda: 2742.24
#       subsample: 0.999773
#     timestamp: 1754674922.5804431
#     timestamp_dt: 2025-08-08 17:42:02.580443136
#
# #14 — test_mse: 0.013171  (iteration 580, time 2025-08-08 18:00:18.937735168)
#   ── Full row:
#     iteration: 580
#     train_mse: 0.029108
#     train_r2: 0.031435
#     test_mse: 0.013171
#     test_r2: 0.004992
#     params:
#       colsample_bytree: 0.407083
#       device: cuda
#       gamma: 0.49847
#       learning_rate: 0.137873
#       max_depth: 15
#       min_child_weight: 10
#       n_estimators: 2750
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 425.808
#       reg_lambda: 2992.58
#       subsample: 0.971395
#     timestamp: 1754676018.937735
#     timestamp_dt: 2025-08-08 18:00:18.937735168
#
# #15 — test_mse: 0.013171  (iteration 951, time 2025-08-08 18:17:51.977806336)
#   ── Full row:
#     iteration: 951
#     train_mse: 0.028416
#     train_r2: 0.054456
#     test_mse: 0.013171
#     test_r2: 0.004989
#     params:
#       colsample_bytree: 0.394429
#       device: cuda
#       gamma: 0.743299
#       learning_rate: 0.124889
#       max_depth: 7
#       min_child_weight: 13
#       n_estimators: 3350
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 182.789
#       reg_lambda: 1865.06
#       subsample: 0.796129
#     timestamp: 1754677071.9778063
#     timestamp_dt: 2025-08-08 18:17:51.977806336
#
# #16 — test_mse: 0.013173  (iteration 790, time 2025-08-08 18:09:35.998849280)
#   ── Full row:
#     iteration: 790
#     train_mse: 0.028297
#     train_r2: 0.058420
#     test_mse: 0.013173
#     test_r2: 0.004832
#     params:
#       colsample_bytree: 0.560563
#       device: cuda
#       gamma: 1.32547
#       learning_rate: 0.130317
#       max_depth: 9
#       min_child_weight: 6
#       n_estimators: 2600
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 144.448
#       reg_lambda: 4265.46
#       subsample: 0.879567
#     timestamp: 1754676575.9988494
#     timestamp_dt: 2025-08-08 18:09:35.998849280
#
# #17 — test_mse: 0.013174  (iteration 390, time 2025-08-08 17:52:41.098919424)
#   ── Full row:
#     iteration: 390
#     train_mse: 0.028730
#     train_r2: 0.044007
#     test_mse: 0.013174
#     test_r2: 0.004773
#     params:
#       colsample_bytree: 0.233884
#       device: cuda
#       gamma: 0.699166
#       learning_rate: 0.0736516
#       max_depth: 4
#       min_child_weight: 7
#       n_estimators: 1150
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 139.107
#       reg_lambda: 8037.89
#       subsample: 0.697908
#     timestamp: 1754675561.0989194
#     timestamp_dt: 2025-08-08 17:52:41.098919424
#
# #18 — test_mse: 0.013177  (iteration 692, time 2025-08-08 18:04:59.952424704)
#   ── Full row:
#     iteration: 692
#     train_mse: 0.028550
#     train_r2: 0.050015
#     test_mse: 0.013177
#     test_r2: 0.004532
#     params:
#       colsample_bytree: 0.382238
#       device: cuda
#       gamma: 0.678644
#       learning_rate: 0.183792
#       max_depth: 7
#       min_child_weight: 10
#       n_estimators: 2400
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 245.536
#       reg_lambda: 1637.3
#       subsample: 0.923898
#     timestamp: 1754676299.9524248
#     timestamp_dt: 2025-08-08 18:04:59.952424704
#
# #19 — test_mse: 0.013179  (iteration 563, time 2025-08-08 17:59:27.321675520)
#   ── Full row:
#     iteration: 563
#     train_mse: 0.029424
#     train_r2: 0.020930
#     test_mse: 0.013179
#     test_r2: 0.004390
#     params:
#       colsample_bytree: 0.40632
#       device: cuda
#       gamma: 1.09408
#       learning_rate: 0.157158
#       max_depth: 7
#       min_child_weight: 9
#       n_estimators: 850
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 368.98
#       reg_lambda: 3005.11
#       subsample: 0.837789
#     timestamp: 1754675967.3216755
#     timestamp_dt: 2025-08-08 17:59:27.321675520
#
# #20 — test_mse: 0.013180  (iteration 1007, time 2025-08-08 18:20:32.968046848)
#   ── Full row:
#     iteration: 1007
#     train_mse: 0.029021
#     train_r2: 0.034339
#     test_mse: 0.013180
#     test_r2: 0.004304
#     params:
#       colsample_bytree: 0.406589
#       device: cuda
#       gamma: 0.847445
#       learning_rate: 0.152032
#       max_depth: 14
#       min_child_weight: 9
#       n_estimators: 1100
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 312.28
#       reg_lambda: 3085.7
#       subsample: 0.924408
#     timestamp: 1754677232.968047
#     timestamp_dt: 2025-08-08 18:20:32.968046848
#
# ====================================================================================================
# Top 20 HIGHEST train_r2
# ====================================================================================================
# #01 — train_r2: 0.833303  (iteration 249, time 2025-08-08 17:45:44.365824)
#   ── Full row:
#     iteration: 249
#     train_mse: 0.005010
#     train_r2: 0.833303
#     test_mse: 0.018217
#     test_r2: -0.376188
#     params:
#       colsample_bytree: 0.360569
#       device: cuda
#       gamma: 0.00330282
#       learning_rate: 0.184417
#       max_depth: 9
#       min_child_weight: 8
#       n_estimators: 3250
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 24.7185
#       reg_lambda: 4214.83
#       subsample: 0.547832
#     timestamp: 1754675144.365824
#     timestamp_dt: 2025-08-08 17:45:44.365824
#
# #02 — train_r2: 0.717809  (iteration 681, time 2025-08-08 18:04:30.457833984)
#   ── Full row:
#     iteration: 681
#     train_mse: 0.008481
#     train_r2: 0.717809
#     test_mse: 0.016640
#     test_r2: -0.257106
#     params:
#       colsample_bytree: 0.449734
#       device: cuda
#       gamma: 0.0327927
#       learning_rate: 0.129122
#       max_depth: 6
#       min_child_weight: 10
#       n_estimators: 1850
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 14.5341
#       reg_lambda: 1177.81
#       subsample: 0.911686
#     timestamp: 1754676270.457834
#     timestamp_dt: 2025-08-08 18:04:30.457833984
#
# #03 — train_r2: 0.680952  (iteration 382, time 2025-08-08 17:52:20.129754368)
#   ── Full row:
#     iteration: 382
#     train_mse: 0.009588
#     train_r2: 0.680952
#     test_mse: 0.015351
#     test_r2: -0.159725
#     params:
#       colsample_bytree: 0.390525
#       device: cuda
#       gamma: 0.122221
#       learning_rate: 0.179353
#       max_depth: 11
#       min_child_weight: 9
#       n_estimators: 3550
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 0.884505
#       reg_lambda: 3955.08
#       subsample: 0.985095
#     timestamp: 1754675540.1297543
#     timestamp_dt: 2025-08-08 17:52:20.129754368
#
# #04 — train_r2: 0.673643  (iteration 956, time 2025-08-08 18:18:04.205077504)
#   ── Full row:
#     iteration: 956
#     train_mse: 0.009808
#     train_r2: 0.673643
#     test_mse: 0.014630
#     test_r2: -0.105202
#     params:
#       colsample_bytree: 0.48405
#       device: cuda
#       gamma: 0.216204
#       learning_rate: 0.134295
#       max_depth: 14
#       min_child_weight: 8
#       n_estimators: 1600
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 0.0571033
#       reg_lambda: 2632.02
#       subsample: 0.953736
#     timestamp: 1754677084.2050774
#     timestamp_dt: 2025-08-08 18:18:04.205077504
#
# #05 — train_r2: 0.663190  (iteration 689, time 2025-08-08 18:04:52.510065408)
#   ── Full row:
#     iteration: 689
#     train_mse: 0.010122
#     train_r2: 0.663190
#     test_mse: 0.015194
#     test_r2: -0.147827
#     params:
#       colsample_bytree: 0.282048
#       device: cuda
#       gamma: 0.165751
#       learning_rate: 0.1386
#       max_depth: 9
#       min_child_weight: 12
#       n_estimators: 3150
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 0.0638032
#       reg_lambda: 1405.61
#       subsample: 0.863396
#     timestamp: 1754676292.5100653
#     timestamp_dt: 2025-08-08 18:04:52.510065408
#
# #06 — train_r2: 0.649633  (iteration 748, time 2025-08-08 18:07:33.701985792)
#   ── Full row:
#     iteration: 748
#     train_mse: 0.010529
#     train_r2: 0.649633
#     test_mse: 0.015028
#     test_r2: -0.135311
#     params:
#       colsample_bytree: 0.56739
#       device: cuda
#       gamma: 0.21292
#       learning_rate: 0.215117
#       max_depth: 14
#       min_child_weight: 9
#       n_estimators: 1500
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 5.24811
#       reg_lambda: 2702.64
#       subsample: 0.883699
#     timestamp: 1754676453.7019858
#     timestamp_dt: 2025-08-08 18:07:33.701985792
#
# #07 — train_r2: 0.631326  (iteration 569, time 2025-08-08 17:59:40.086947072)
#   ── Full row:
#     iteration: 569
#     train_mse: 0.011080
#     train_r2: 0.631326
#     test_mse: 0.014878
#     test_r2: -0.123972
#     params:
#       colsample_bytree: 0.602452
#       device: cuda
#       gamma: 0.00575772
#       learning_rate: 0.150733
#       max_depth: 11
#       min_child_weight: 12
#       n_estimators: 150
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 6.9004
#       reg_lambda: 3665.91
#       subsample: 0.915792
#     timestamp: 1754675980.086947
#     timestamp_dt: 2025-08-08 17:59:40.086947072
#
# #08 — train_r2: 0.608284  (iteration 482, time 2025-08-08 17:55:06.548829696)
#   ── Full row:
#     iteration: 482
#     train_mse: 0.011772
#     train_r2: 0.608284
#     test_mse: 0.015226
#     test_r2: -0.150227
#     params:
#       colsample_bytree: 0.368509
#       device: cuda
#       gamma: 0.0826047
#       learning_rate: 0.111115
#       max_depth: 8
#       min_child_weight: 9
#       n_estimators: 500
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 12.8563
#       reg_lambda: 3347.82
#       subsample: 0.971042
#     timestamp: 1754675706.5488298
#     timestamp_dt: 2025-08-08 17:55:06.548829696
#
# #09 — train_r2: 0.590538  (iteration 477, time 2025-08-08 17:54:58.830246656)
#   ── Full row:
#     iteration: 477
#     train_mse: 0.012305
#     train_r2: 0.590538
#     test_mse: 0.014445
#     test_r2: -0.091283
#     params:
#       colsample_bytree: 0.431171
#       device: cuda
#       gamma: 0.251761
#       learning_rate: 0.0911019
#       max_depth: 13
#       min_child_weight: 10
#       n_estimators: 650
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 11.1112
#       reg_lambda: 2353.15
#       subsample: 0.983271
#     timestamp: 1754675698.8302467
#     timestamp_dt: 2025-08-08 17:54:58.830246656
#
# #10 — train_r2: 0.581456  (iteration 369, time 2025-08-08 17:51:42.106733056)
#   ── Full row:
#     iteration: 369
#     train_mse: 0.012578
#     train_r2: 0.581456
#     test_mse: 0.014670
#     test_r2: -0.108229
#     params:
#       colsample_bytree: 0.429607
#       device: cuda
#       gamma: 0.309094
#       learning_rate: 0.201217
#       max_depth: 24
#       min_child_weight: 12
#       n_estimators: 2350
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 1.53806
#       reg_lambda: 5160.84
#       subsample: 0.961549
#     timestamp: 1754675502.106733
#     timestamp_dt: 2025-08-08 17:51:42.106733056
#
# #11 — train_r2: 0.551131  (iteration 990, time 2025-08-08 18:19:45.643872512)
#   ── Full row:
#     iteration: 990
#     train_mse: 0.013490
#     train_r2: 0.551131
#     test_mse: 0.014055
#     test_r2: -0.061769
#     params:
#       colsample_bytree: 0.459051
#       device: cuda
#       gamma: 0.340061
#       learning_rate: 0.0931071
#       max_depth: 12
#       min_child_weight: 10
#       n_estimators: 1300
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 3.56998
#       reg_lambda: 1886.06
#       subsample: 0.923
#     timestamp: 1754677185.6438725
#     timestamp_dt: 2025-08-08 18:19:45.643872512
#
# #12 — train_r2: 0.547702  (iteration 838, time 2025-08-08 18:12:03.660814336)
#   ── Full row:
#     iteration: 838
#     train_mse: 0.013593
#     train_r2: 0.547702
#     test_mse: 0.014929
#     test_r2: -0.127810
#     params:
#       colsample_bytree: 0.536197
#       device: cuda
#       gamma: 0.18965
#       learning_rate: 0.159346
#       max_depth: 9
#       min_child_weight: 11
#       n_estimators: 1800
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 14.0238
#       reg_lambda: 3745.74
#       subsample: 0.983713
#     timestamp: 1754676723.6608143
#     timestamp_dt: 2025-08-08 18:12:03.660814336
#
# #13 — train_r2: 0.527189  (iteration 759, time 2025-08-08 18:08:04.423654144)
#   ── Full row:
#     iteration: 759
#     train_mse: 0.014209
#     train_r2: 0.527189
#     test_mse: 0.014144
#     test_r2: -0.068510
#     params:
#       colsample_bytree: 0.455343
#       device: cuda
#       gamma: 0.640364
#       learning_rate: 0.210019
#       max_depth: 15
#       min_child_weight: 11
#       n_estimators: 2050
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 0.948199
#       reg_lambda: 813.136
#       subsample: 0.880269
#     timestamp: 1754676484.423654
#     timestamp_dt: 2025-08-08 18:08:04.423654144
#
# #14 — train_r2: 0.514747  (iteration 335, time 2025-08-08 17:50:04.059897088)
#   ── Full row:
#     iteration: 335
#     train_mse: 0.014583
#     train_r2: 0.514747
#     test_mse: 0.014760
#     test_r2: -0.115070
#     params:
#       colsample_bytree: 0.507286
#       device: cuda
#       gamma: 0.316546
#       learning_rate: 0.279661
#       max_depth: 22
#       min_child_weight: 11
#       n_estimators: 1550
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 14.6176
#       reg_lambda: 3725.58
#       subsample: 0.80845
#     timestamp: 1754675404.0598972
#     timestamp_dt: 2025-08-08 17:50:04.059897088
#
# #15 — train_r2: 0.507676  (iteration 491, time 2025-08-08 17:55:28.081819904)
#   ── Full row:
#     iteration: 491
#     train_mse: 0.014796
#     train_r2: 0.507676
#     test_mse: 0.015017
#     test_r2: -0.134450
#     params:
#       colsample_bytree: 0.379059
#       device: cuda
#       gamma: 0.195717
#       learning_rate: 0.160482
#       max_depth: 7
#       min_child_weight: 13
#       n_estimators: 1400
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 12.7782
#       reg_lambda: 2912.1
#       subsample: 0.969727
#     timestamp: 1754675728.08182
#     timestamp_dt: 2025-08-08 17:55:28.081819904
#
# #16 — train_r2: 0.490879  (iteration 297, time 2025-08-08 17:48:00.627092992)
#   ── Full row:
#     iteration: 297
#     train_mse: 0.015301
#     train_r2: 0.490879
#     test_mse: 0.014347
#     test_r2: -0.083876
#     params:
#       colsample_bytree: 0.820275
#       device: cuda
#       gamma: 0.601108
#       learning_rate: 0.184466
#       max_depth: 14
#       min_child_weight: 8
#       n_estimators: 2200
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 2.18328
#       reg_lambda: 2444.49
#       subsample: 0.983654
#     timestamp: 1754675280.627093
#     timestamp_dt: 2025-08-08 17:48:00.627092992
#
# #17 — train_r2: 0.487595  (iteration 303, time 2025-08-08 17:48:20.640445184)
#   ── Full row:
#     iteration: 303
#     train_mse: 0.015399
#     train_r2: 0.487595
#     test_mse: 0.014220
#     test_r2: -0.074223
#     params:
#       colsample_bytree: 0.565748
#       device: cuda
#       gamma: 0.413392
#       learning_rate: 0.150066
#       max_depth: 21
#       min_child_weight: 11
#       n_estimators: 2500
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 17.4095
#       reg_lambda: 3560.58
#       subsample: 0.924913
#     timestamp: 1754675300.6404452
#     timestamp_dt: 2025-08-08 17:48:20.640445184
#
# #18 — train_r2: 0.469134  (iteration 620, time 2025-08-08 18:02:07.729071616)
#   ── Full row:
#     iteration: 620
#     train_mse: 0.015954
#     train_r2: 0.469134
#     test_mse: 0.014153
#     test_r2: -0.069179
#     params:
#       colsample_bytree: 0.413967
#       device: cuda
#       gamma: 0.342243
#       learning_rate: 0.192011
#       max_depth: 9
#       min_child_weight: 7
#       n_estimators: 2800
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 11.5402
#       reg_lambda: 3428.79
#       subsample: 0.982367
#     timestamp: 1754676127.7290716
#     timestamp_dt: 2025-08-08 18:02:07.729071616
#
# #19 — train_r2: 0.458547  (iteration 975, time 2025-08-08 18:19:01.182672384)
#   ── Full row:
#     iteration: 975
#     train_mse: 0.016272
#     train_r2: 0.458547
#     test_mse: 0.014507
#     test_r2: -0.095967
#     params:
#       colsample_bytree: 0.569755
#       device: cuda
#       gamma: 0.727008
#       learning_rate: 0.266131
#       max_depth: 14
#       min_child_weight: 9
#       n_estimators: 2400
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 4.9716
#       reg_lambda: 1497.04
#       subsample: 0.91505
#     timestamp: 1754677141.1826725
#     timestamp_dt: 2025-08-08 18:19:01.182672384
#
# #20 — train_r2: 0.453853  (iteration 188, time 2025-08-08 17:42:06.604801024)
#   ── Full row:
#     iteration: 188
#     train_mse: 0.016413
#     train_r2: 0.453853
#     test_mse: 0.013909
#     test_r2: -0.050730
#     params:
#       colsample_bytree: 0.392856
#       device: cuda
#       gamma: 0.461047
#       learning_rate: 0.117176
#       max_depth: 9
#       min_child_weight: 9
#       n_estimators: 3000
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 1.21086
#       reg_lambda: 2353.91
#       subsample: 0.977964
#     timestamp: 1754674926.604801
#     timestamp_dt: 2025-08-08 17:42:06.604801024
#
# ====================================================================================================
# Top 20 HIGHEST test_r2
# ====================================================================================================
# #01 — test_r2: 0.009950  (iteration 741, time 2025-08-08 18:07:16.230345472)
#   ── Full row:
#     iteration: 741
#     train_mse: 0.028682
#     train_r2: 0.045608
#     test_mse: 0.013105
#     test_r2: 0.009950
#     params:
#       colsample_bytree: 0.500413
#       device: cuda
#       gamma: 1.07788
#       learning_rate: 0.208581
#       max_depth: 14
#       min_child_weight: 8
#       n_estimators: 2150
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 220.784
#       reg_lambda: 3650.31
#       subsample: 0.876951
#     timestamp: 1754676436.2303455
#     timestamp_dt: 2025-08-08 18:07:16.230345472
#
# #02 — test_r2: 0.007447  (iteration 808, time 2025-08-08 18:10:27.705774848)
#   ── Full row:
#     iteration: 808
#     train_mse: 0.028512
#     train_r2: 0.051271
#     test_mse: 0.013138
#     test_r2: 0.007447
#     params:
#       colsample_bytree: 0.492154
#       device: cuda
#       gamma: 1.28789
#       learning_rate: 0.147052
#       max_depth: 8
#       min_child_weight: 10
#       n_estimators: 2550
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 175.098
#       reg_lambda: 4315.91
#       subsample: 0.873144
#     timestamp: 1754676627.7057748
#     timestamp_dt: 2025-08-08 18:10:27.705774848
#
# #03 — test_r2: 0.007232  (iteration 194, time 2025-08-08 17:42:25.917345792)
#   ── Full row:
#     iteration: 194
#     train_mse: 0.029373
#     train_r2: 0.022615
#     test_mse: 0.013141
#     test_r2: 0.007232
#     params:
#       colsample_bytree: 0.379297
#       device: cuda
#       gamma: 0.120228
#       learning_rate: 0.160559
#       max_depth: 8
#       min_child_weight: 10
#       n_estimators: 3300
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 611.589
#       reg_lambda: 3707.07
#       subsample: 0.971439
#     timestamp: 1754674945.9173458
#     timestamp_dt: 2025-08-08 17:42:25.917345792
#
# #04 — test_r2: 0.006460  (iteration 505, time 2025-08-08 17:55:59.500998400)
#   ── Full row:
#     iteration: 505
#     train_mse: 0.028409
#     train_r2: 0.054695
#     test_mse: 0.013151
#     test_r2: 0.006460
#     params:
#       colsample_bytree: 0.409729
#       device: cuda
#       gamma: 0.723668
#       learning_rate: 0.148242
#       max_depth: 9
#       min_child_weight: 9
#       n_estimators: 3750
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 220.347
#       reg_lambda: 2276.78
#       subsample: 0.847024
#     timestamp: 1754675759.5009985
#     timestamp_dt: 2025-08-08 17:55:59.500998400
#
# #05 — test_r2: 0.006300  (iteration 631, time 2025-08-08 18:02:35.640585984)
#   ── Full row:
#     iteration: 631
#     train_mse: 0.027468
#     train_r2: 0.086019
#     test_mse: 0.013154
#     test_r2: 0.006300
#     params:
#       colsample_bytree: 0.541007
#       device: cuda
#       gamma: 0.791514
#       learning_rate: 0.149848
#       max_depth: 9
#       min_child_weight: 10
#       n_estimators: 1750
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 134.005
#       reg_lambda: 3529.96
#       subsample: 0.838053
#     timestamp: 1754676155.640586
#     timestamp_dt: 2025-08-08 18:02:35.640585984
#
# #06 — test_r2: 0.006014  (iteration 451, time 2025-08-08 17:54:18.900998144)
#   ── Full row:
#     iteration: 451
#     train_mse: 0.029255
#     train_r2: 0.026551
#     test_mse: 0.013157
#     test_r2: 0.006014
#     params:
#       colsample_bytree: 0.470671
#       device: cuda
#       gamma: 0.469475
#       learning_rate: 0.18007
#       max_depth: 7
#       min_child_weight: 8
#       n_estimators: 1450
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 409.476
#       reg_lambda: 2681.08
#       subsample: 0.848005
#     timestamp: 1754675658.900998
#     timestamp_dt: 2025-08-08 17:54:18.900998144
#
# #07 — test_r2: 0.005956  (iteration 186, time 2025-08-08 17:41:59.875205120)
#   ── Full row:
#     iteration: 186
#     train_mse: 0.027764
#     train_r2: 0.076165
#     test_mse: 0.013158
#     test_r2: 0.005956
#     params:
#       colsample_bytree: 0.659737
#       device: cuda
#       gamma: 0.473135
#       learning_rate: 0.209381
#       max_depth: 13
#       min_child_weight: 10
#       n_estimators: 2100
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 250.712
#       reg_lambda: 3676.15
#       subsample: 0.999136
#     timestamp: 1754674919.875205
#     timestamp_dt: 2025-08-08 17:41:59.875205120
#
# #08 — test_r2: 0.005624  (iteration 469, time 2025-08-08 17:54:47.793163008)
#   ── Full row:
#     iteration: 469
#     train_mse: 0.028490
#     train_r2: 0.052006
#     test_mse: 0.013163
#     test_r2: 0.005624
#     params:
#       colsample_bytree: 0.42213
#       device: cuda
#       gamma: 0.810567
#       learning_rate: 0.110057
#       max_depth: 10
#       min_child_weight: 10
#       n_estimators: 850
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 208.497
#       reg_lambda: 2277.4
#       subsample: 0.892466
#     timestamp: 1754675687.793163
#     timestamp_dt: 2025-08-08 17:54:47.793163008
#
# #09 — test_r2: 0.005601  (iteration 711, time 2025-08-08 18:05:45.434233600)
#   ── Full row:
#     iteration: 711
#     train_mse: 0.028115
#     train_r2: 0.064464
#     test_mse: 0.013163
#     test_r2: 0.005601
#     params:
#       colsample_bytree: 0.517818
#       device: cuda
#       gamma: 1.06602
#       learning_rate: 0.133584
#       max_depth: 6
#       min_child_weight: 7
#       n_estimators: 2450
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 152.123
#       reg_lambda: 3625.2
#       subsample: 0.9034
#     timestamp: 1754676345.4342337
#     timestamp_dt: 2025-08-08 18:05:45.434233600
#
# #10 — test_r2: 0.005528  (iteration 389, time 2025-08-08 17:52:39.363936)
#   ── Full row:
#     iteration: 389
#     train_mse: 0.028865
#     train_r2: 0.039515
#     test_mse: 0.013164
#     test_r2: 0.005528
#     params:
#       colsample_bytree: 0.344951
#       device: cuda
#       gamma: 0.854488
#       learning_rate: 0.122423
#       max_depth: 5
#       min_child_weight: 10
#       n_estimators: 450
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 207.242
#       reg_lambda: 6219.59
#       subsample: 0.828809
#     timestamp: 1754675559.363936
#     timestamp_dt: 2025-08-08 17:52:39.363936
#
# #11 — test_r2: 0.005083  (iteration 943, time 2025-08-08 18:17:28.532270848)
#   ── Full row:
#     iteration: 943
#     train_mse: 0.028401
#     train_r2: 0.054960
#     test_mse: 0.013170
#     test_r2: 0.005083
#     params:
#       colsample_bytree: 0.50607
#       device: cuda
#       gamma: 1.058
#       learning_rate: 0.0731066
#       max_depth: 10
#       min_child_weight: 13
#       n_estimators: 1950
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 171.891
#       reg_lambda: 3692.59
#       subsample: 0.841883
#     timestamp: 1754677048.532271
#     timestamp_dt: 2025-08-08 18:17:28.532270848
#
# #12 — test_r2: 0.005018  (iteration 921, time 2025-08-08 18:16:16.081352704)
#   ── Full row:
#     iteration: 921
#     train_mse: 0.029271
#     train_r2: 0.026014
#     test_mse: 0.013171
#     test_r2: 0.005018
#     params:
#       colsample_bytree: 0.624017
#       device: cuda
#       gamma: 0.264118
#       learning_rate: 0.198227
#       max_depth: 6
#       min_child_weight: 6
#       n_estimators: 950
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 459.194
#       reg_lambda: 2483.01
#       subsample: 0.877294
#     timestamp: 1754676976.0813527
#     timestamp_dt: 2025-08-08 18:16:16.081352704
#
# #13 — test_r2: 0.004998  (iteration 187, time 2025-08-08 17:42:02.580443136)
#   ── Full row:
#     iteration: 187
#     train_mse: 0.028129
#     train_r2: 0.064001
#     test_mse: 0.013171
#     test_r2: 0.004998
#     params:
#       colsample_bytree: 0.392667
#       device: cuda
#       gamma: 0.480634
#       learning_rate: 0.159308
#       max_depth: 13
#       min_child_weight: 10
#       n_estimators: 2100
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 250.986
#       reg_lambda: 2742.24
#       subsample: 0.999773
#     timestamp: 1754674922.5804431
#     timestamp_dt: 2025-08-08 17:42:02.580443136
#
# #14 — test_r2: 0.004992  (iteration 580, time 2025-08-08 18:00:18.937735168)
#   ── Full row:
#     iteration: 580
#     train_mse: 0.029108
#     train_r2: 0.031435
#     test_mse: 0.013171
#     test_r2: 0.004992
#     params:
#       colsample_bytree: 0.407083
#       device: cuda
#       gamma: 0.49847
#       learning_rate: 0.137873
#       max_depth: 15
#       min_child_weight: 10
#       n_estimators: 2750
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 425.808
#       reg_lambda: 2992.58
#       subsample: 0.971395
#     timestamp: 1754676018.937735
#     timestamp_dt: 2025-08-08 18:00:18.937735168
#
# #15 — test_r2: 0.004989  (iteration 951, time 2025-08-08 18:17:51.977806336)
#   ── Full row:
#     iteration: 951
#     train_mse: 0.028416
#     train_r2: 0.054456
#     test_mse: 0.013171
#     test_r2: 0.004989
#     params:
#       colsample_bytree: 0.394429
#       device: cuda
#       gamma: 0.743299
#       learning_rate: 0.124889
#       max_depth: 7
#       min_child_weight: 13
#       n_estimators: 3350
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 182.789
#       reg_lambda: 1865.06
#       subsample: 0.796129
#     timestamp: 1754677071.9778063
#     timestamp_dt: 2025-08-08 18:17:51.977806336
#
# #16 — test_r2: 0.004832  (iteration 790, time 2025-08-08 18:09:35.998849280)
#   ── Full row:
#     iteration: 790
#     train_mse: 0.028297
#     train_r2: 0.058420
#     test_mse: 0.013173
#     test_r2: 0.004832
#     params:
#       colsample_bytree: 0.560563
#       device: cuda
#       gamma: 1.32547
#       learning_rate: 0.130317
#       max_depth: 9
#       min_child_weight: 6
#       n_estimators: 2600
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 144.448
#       reg_lambda: 4265.46
#       subsample: 0.879567
#     timestamp: 1754676575.9988494
#     timestamp_dt: 2025-08-08 18:09:35.998849280
#
# #17 — test_r2: 0.004773  (iteration 390, time 2025-08-08 17:52:41.098919424)
#   ── Full row:
#     iteration: 390
#     train_mse: 0.028730
#     train_r2: 0.044007
#     test_mse: 0.013174
#     test_r2: 0.004773
#     params:
#       colsample_bytree: 0.233884
#       device: cuda
#       gamma: 0.699166
#       learning_rate: 0.0736516
#       max_depth: 4
#       min_child_weight: 7
#       n_estimators: 1150
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 139.107
#       reg_lambda: 8037.89
#       subsample: 0.697908
#     timestamp: 1754675561.0989194
#     timestamp_dt: 2025-08-08 17:52:41.098919424
#
# #18 — test_r2: 0.004532  (iteration 692, time 2025-08-08 18:04:59.952424704)
#   ── Full row:
#     iteration: 692
#     train_mse: 0.028550
#     train_r2: 0.050015
#     test_mse: 0.013177
#     test_r2: 0.004532
#     params:
#       colsample_bytree: 0.382238
#       device: cuda
#       gamma: 0.678644
#       learning_rate: 0.183792
#       max_depth: 7
#       min_child_weight: 10
#       n_estimators: 2400
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 245.536
#       reg_lambda: 1637.3
#       subsample: 0.923898
#     timestamp: 1754676299.9524248
#     timestamp_dt: 2025-08-08 18:04:59.952424704
#
# #19 — test_r2: 0.004390  (iteration 563, time 2025-08-08 17:59:27.321675520)
#   ── Full row:
#     iteration: 563
#     train_mse: 0.029424
#     train_r2: 0.020930
#     test_mse: 0.013179
#     test_r2: 0.004390
#     params:
#       colsample_bytree: 0.40632
#       device: cuda
#       gamma: 1.09408
#       learning_rate: 0.157158
#       max_depth: 7
#       min_child_weight: 9
#       n_estimators: 850
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 368.98
#       reg_lambda: 3005.11
#       subsample: 0.837789
#     timestamp: 1754675967.3216755
#     timestamp_dt: 2025-08-08 17:59:27.321675520
#
# #20 — test_r2: 0.004304  (iteration 1007, time 2025-08-08 18:20:32.968046848)
#   ── Full row:
#     iteration: 1007
#     train_mse: 0.029021
#     train_r2: 0.034339
#     test_mse: 0.013180
#     test_r2: 0.004304
#     params:
#       colsample_bytree: 0.406589
#       device: cuda
#       gamma: 0.847445
#       learning_rate: 0.152032
#       max_depth: 14
#       min_child_weight: 9
#       n_estimators: 1100
#       n_jobs: -1
#       objective: reg:squarederror
#       random_state: 42
#       reg_alpha: 312.28
#       reg_lambda: 3085.7
#       subsample: 0.924408
#     timestamp: 1754677232.968047
#     timestamp_dt: 2025-08-08 18:20:32.968046848
